# %%
from libs.libforex import ForexPair

# %%
xauusd = ForexPair("XAUUSD")
filename = "XAUUSD1440"
xauusd.read_csv("D:\\LABS\\histdata\\xauusd\\"+filename+".csv")

# %%
xauusd.dataframe
# Out:
#             Date_Time     Open     High      Low    Close  Volume
# Date_Time
# 1998-04-22 1998-04-22   312.60   315.20   311.90   314.30     491
# 1998-04-23 1998-04-23   313.40   314.20   311.80   312.90     431
# 1998-04-27 1998-04-27   309.39   310.90   306.30   308.20     802
# 1998-04-28 1998-04-28   307.65   311.40   307.00   310.50     596
# 1998-04-29 1998-04-29   310.79   312.10   305.50   306.90     932
# ...               ...      ...      ...      ...      ...     ...
# 2021-07-30 2021-07-30  1828.33  1831.30  1810.25  1814.25   75478
# 2021-08-02 2021-08-02  1813.78  1819.49  1805.75  1813.10   82434
# 2021-08-03 2021-08-03  1813.11  1814.93  1807.06  1810.10   67913
# 2021-08-04 2021-08-04  1810.25  1831.66  1806.49  1811.47   83965
# 2021-08-05 2021-08-05  1811.95  1814.58  1808.38  1810.20   26291
#
# [5518 rows x 6 columns]

# %%
mx = xauusd.get_market_closing_extreme(mode="all")
mx
# Out:
#             Date_Time    Close
# Date_Time
# 1998-04-30 1998-04-30   314.30
# 1998-04-30 1998-04-22   302.50
# 1998-05-31 1998-05-04   293.20
# 1998-05-31 1998-05-28   303.60
# 1998-06-30 1998-06-30   299.00
# ...               ...      ...
# 2021-06-30 2021-06-30  1908.66
# 2021-07-31 2021-07-01  1776.52
# 2021-07-31 2021-07-30  1829.45
# 2021-08-31 2021-08-05  1813.10
# 2021-08-31 2021-08-02  1810.10
#
# [562 rows x 2 columns]

# %%
mx.to_excel('marc-XAUUSD.xlsx', index=False)

# %%
mx['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date_Time'>
